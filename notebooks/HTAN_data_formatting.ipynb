# %%
import re
import os





# import scanpy as sc
import pandas as pd
import numpy as np
# import anndata
import matplotlib.pyplot as plt
import mgitools.os_helpers as os_helpers

from skimage.io import imread
from skimage import exposure
# Out:
# /data/estorrs/miniconda3/envs/imaging_analysis/lib/python3.7/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
# from imctools.io.mcd.mcdparser import McdParser

# %%
def normalize_sample_name(name):
    name = name.replace(' ', '_')
    return name

# %%
# !pip install ome-types

# %%
# batch_folder = 'b1_01042020_processed_05242021'
batch_folder = 'HT308B1-H5A4'

# batch_folder = 'adult_kidney'

# %% [markdown]
# ## generate ome.tiff from hyperion .mcd

# %%
fps = os_helpers.listfiles(f'../data/hyperion/{batch_folder}/mcd/')
# fps = [fp for fp in fps if 'HT056' in fp]
sample_fp_tups = [(normalize_sample_name(fp.split('/')[-1].replace('.mcd', '')), fp) for fp in fps]
sample_fp_tups
# Out:
# [('HTAN_HT168P1_S1H2_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT168P1 S1H2 L1 L4.mcd'),
#  ('HTAN_HT122P1_S1H9_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT122P1 S1H9 L1 L4.mcd'),
#  ('HT168P1_S1H3_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HT168P1 S1H3 L1 L4.mcd'),
#  ('HTAN_HT122P1_S1H4_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT122P1 S1H4 L1 L4.mcd'),
#  ('HTAN_HT122P1_S1H5_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT122P1 S1H5 L1 L4.mcd'),
#  ('HTAN_HT166P1_S1H6_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT166P1 S1H6 L1 L4.mcd'),
#  ('HTAN_HT166P1_S1H5_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT166P1 S1H5 L4.mcd'),
#  ('HTAN_HT124P1_S1H1_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT124P1 S1H1 L1 L4.mcd'),
#  ('HTAN_HT168P1_S1H4_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT168P1 S1H4 L1 L4.mcd'),
#  ('HTAN_HT124P1_S1H4_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT124P1 S1H4 L1 L4.mcd'),
#  ('HTAN_HT123P1_S1H3_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT123P1 S1H3 L1 L4.mcd'),
#  ('HTAN_HT166P1_S1H2_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT166P1 S1H2 L1 L4.mcd'),
#  ('HTAN_HT123P1_S1H5_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT123P1 S1H5 L1 L4.mcd'),
#  ('HTAN_HT123P1_S1H1_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT123P1 S1H1 L1 L4.mcd'),
#  ('HTAN_HT124P1S1H2_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT124P1S1H2 L1 L4.mcd'),
#  ('HTAN_HT122P1_S1H3_L1_L4',
#   '../data/hyperion/b2_06252020_processed_10072021/mcd/HTAN HT122P1 S1H3 L1 L4.mcd')]

# %%
out_dir = f'../data/hyperion/{batch_folder}/ome-tiff'
from pathlib import Path
Path(out_dir).mkdir(exist_ok=True, parents=True)

# %%
# parser = McdParser(sample_fp_tups[0][1])
# session = parser.session
# # Get all acquisition IDs
# ids = parser.session.acquisition_ids
# ac_data = parser.get_acquisition_data(ids[0], )

# %%
# ac_data.save_ome_tiff(os.path.join(out_dir, f'test.ome.tiff'), )

# %%
def mcd_to_ome(sample_id, fp, out_dir):
    """reads .mcd file and return ome.tiff with HTAN required metadata"""
    parser = McdParser(fp)
    session = parser.session
    # Get all acquisition IDs
    ids = parser.session.acquisition_ids
    
    for a_id in ids:
#         print(fp, a_id)
        try:
            ac_data = parser.get_acquisition_data(a_id)
            metadata = ac_data.acquisition.metadata
            roi = metadata['Description'].replace(' ', '_')
            print(f'{sample_id}_{roi}.ome.tiff')
            ac_data.save_ome_tiff(os.path.join(out_dir, f'{sample_id}_{roi}.ome.tiff'), )
        except ValueError:
            print(f'error loading data for {sample_id}, {fp}, {a_id}')

# %%
for s, fp in sample_fp_tups:
    mcd_to_ome(s, fp, out_dir)
# Out:
# HTAN_HT168P1_S1H2_L1_L4_ROI_001.ome.tiff
# HTAN_HT168P1_S1H2_L1_L4_ROI_002.ome.tiff
# HTAN_HT122P1_S1H9_L1_L4_ROI_001.ome.tiff
# HTAN_HT122P1_S1H9_L1_L4_ROI_002.ome.tiff
# HT168P1_S1H3_L1_L4_ROI_001.ome.tiff
# HT168P1_S1H3_L1_L4_ROI_002.ome.tiff
# HT168P1_S1H3_L1_L4_ROI_003.ome.tiff
# HTAN_HT122P1_S1H4_L1_L4_ROI_001.ome.tiff
# HTAN_HT122P1_S1H4_L1_L4_ROI_002.ome.tiff
# HTAN_HT122P1_S1H5_L1_L4_ROI_001.ome.tiff
# HTAN_HT122P1_S1H5_L1_L4_ROI_002.ome.tiff
# HTAN_HT166P1_S1H6_L1_L4_ROI_001.ome.tiff
# HTAN_HT166P1_S1H6_L1_L4_ROI_002.ome.tiff
# HTAN_HT166P1_S1H5_L4_ROI_001.ome.tiff
# HTAN_HT166P1_S1H5_L4_ROI_002.ome.tiff
# HTAN_HT166P1_S1H5_L4_ROI_003.ome.tiff
# HTAN_HT124P1_S1H1_L1_L4_ROI_001.ome.tiff
# HTAN_HT124P1_S1H1_L1_L4_ROI_002.ome.tiff
# HTAN_HT168P1_S1H4_L1_L4_ROI_001.ome.tiff
# HTAN_HT168P1_S1H4_L1_L4_ROI_002.ome.tiff
# HTAN_HT168P1_S1H4_L1_L4_ROI_003.ome.tiff
# HTAN_HT124P1_S1H4_L1_L4_ROI_001.ome.tiff
# HTAN_HT124P1_S1H4_L1_L4_ROI_002.ome.tiff
# HTAN_HT124P1_S1H4_L1_L4_ROI_003.ome.tiff
# HTAN_HT124P1_S1H4_L1_L4_ROI_004.ome.tiff
# HTAN_HT124P1_S1H4_L1_L4_ROI_005.ome.tiff
# HTAN_HT123P1_S1H3_L1_L4_ROI_001.ome.tiff
# HTAN_HT123P1_S1H3_L1_L4_ROI_002.ome.tiff
# HTAN_HT166P1_S1H2_L1_L4_ROI_001.ome.tiff
# HTAN_HT166P1_S1H2_L1_L4_ROI_002.ome.tiff
# HTAN_HT123P1_S1H5_L1_L4_ROI_001.ome.tiff
# HTAN_HT123P1_S1H5_L1_L4_ROI_002.ome.tiff
# HTAN_HT123P1_S1H1_L1_L4_ROI_001.ome.tiff
# HTAN_HT123P1_S1H1_L1_L4_ROI_002.ome.tiff
# HTAN_HT124P1S1H2_L1_L4_ROI_001.ome.tiff
# HTAN_HT124P1S1H2_L1_L4_ROI_002.ome.tiff
# HTAN_HT122P1_S1H3_L1_L4_ROI_001.ome.tiff
# HTAN_HT122P1_S1H3_L1_L4_ROI_002.ome.tiff
# HTAN_HT122P1_S1H3_L1_L4_ROI_003.ome.tiff

# %% [markdown]
# ## generate level 2 ome.tiffs

# %%
def parse_channel_name_from_raw(c):
    if '-' in c and re.sub(r'^[^-]*-(.*)$', r'\1', c):
        return re.sub(r'^[^-]*-(.*)$', r'\1', c)
    elif '176YbHistoneH3' in c:
        return 'Histone H3'
    return None

def parse_codex_channel_name_from_raw(c):
    pieces = c.split('_')
    c = pieces[-1]
#     print(pieces)
    if 'DAPI1' in c or 'DAPI-01' in c or 'DAPI-1' in c:
        return 'DAPI'
    elif 'DAPI' in c:
        return None
    elif 'blank' in c.lower():
        return None
    elif 'empty' in c.lower():
        return None
    elif 'Experiment' in pieces[0]:
        return None
    return c

# %%
from ome_types import from_tiff, from_xml, to_xml
from ome_types.model.simple_types import UnitsLength
from ome_types.model import Plane

d = {
    'Vimentin': ['vimentin'],
    'Pan Keratin': ['PanCK', 'PanKeratin', 'PanK', 'pancytok', 'PancytoK'],
    'PD-L2': ['PDL2'],
    'PD-L1': ['PDL1'],
    'PD-1': ['PD1'],
    'FOXP3': ['FoxP3'],
    'Granzyme B': ['GranzymeB'],
    'T1 Collagen': ['T1Collagen', 'Type1Coll', 'Type1_collagen'],
    'HLA-DR': ['HLADR'],
    'Histone H3': ['HistoneH3'],
    'Podoplanin': ['podoplanin'],
    'Alpha Amylase': ['AlphaAmylase'],
    'CD3': ['CD3e'],
    'Ecadherin': ['ecadherin'],
    'Histone H3': ['Histone']
    
}
CHANNEL_MAP = {v:k for k, vs in d.items() for v in vs}

def convert_hyperion_ome_to_htan_ome(fp, out_fp):
    tif = TiffFile(fp)
    m = re.sub(r'<Acquis.*AcquisitionDate>', r'', tif.ome_metadata)
    ome = from_xml(m)
    im = ome.images[0]
    im.pixels.physical_size_x = float(im.pixels.size_x)
    im.pixels.physical_size_y = float(im.pixels.size_y)
    im.pixels.physical_size_x_unit = 'µm'
    im.pixels.physical_size_y_unit = 'µm'
    im.pixels.type = 'float'
    
    names = sorted({c.name for c in im.pixels.channels})
    keep = [n for n in names if parse_channel_name_from_raw(n) is not None]
    im.pixels.size_c = len(keep)
    keep_idxs = [i for i, n in enumerate(names) if parse_channel_name_from_raw(n) is not None]
    new = [CHANNEL_MAP.get(parse_channel_name_from_raw(n), parse_channel_name_from_raw(n))
          for n in keep]
    name_to_identifier = {k:n for k, n in zip(keep, new)}
#     print(list(zip(keep, new)))
    im.pixels.channels = [c for c in im.pixels.channels if c.name in keep]
    for c in im.pixels.channels: c.name = name_to_identifier[c.name]
    for i in range(len(im.pixels.channels)): im.pixels.planes.append(Plane(i, 0, 0))
    im.pixels.tiff_data_blocks[0].plane_count = len(im.pixels.channels)
        
    if len(im.pixels.channels):
        xml_str = to_xml(ome)
#         print(xml_str)
        with tifffile.TiffWriter(out_fp, ome=True) as out_tif:
            for i, p in enumerate(tif.pages):
                if i in keep_idxs:
                    out_tif.write(p.asarray().astype(np.int16))
            out_tif.overwrite_description(xml_str.encode())
    else:
        print(f'{fp} has no channels')
        
    return ome

# %%
# im.pixels

# %%
# tif = TiffFile(sample_fp_tups[0][1])
# m = re.sub(r'<Acquis.*AcquisitionDate>', r'', tif.ome_metadata)
# ome = from_xml(m)
# im = ome.images[0]

# %%
# len(im.pixels.channels)

# %%
# for i in range(len(im.pixels.channels)):
#     im.pixels.planes.append(Plane(i, 1, 1))

# %%
# im.pixels.si

# %%
fps = os_helpers.listfiles(f'../data/hyperion/{batch_folder}/ome-tiff')
sample_fp_tups = [(fp.split('/')[-1].replace('.ome.tiff', ''), fp) for fp in fps]
sample_fp_tups
# Out:
# [('HTAN_HT166P1_S1H2_L1_L4_ROI_002',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HTAN_HT166P1_S1H2_L1_L4_ROI_002.ome.tiff'),
#  ('HTAN_HT122P1_S1H4_L1_L4_ROI_002',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HTAN_HT122P1_S1H4_L1_L4_ROI_002.ome.tiff'),
#  ('HT168P1_S1H3_L1_L4_ROI_002',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HT168P1_S1H3_L1_L4_ROI_002.ome.tiff'),
#  ('HTAN_HT123P1_S1H5_L1_L4_ROI_001',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HTAN_HT123P1_S1H5_L1_L4_ROI_001.ome.tiff'),
#  ('HTAN_HT124P1_S1H4_L1_L4_ROI_001',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HTAN_HT124P1_S1H4_L1_L4_ROI_001.ome.tiff'),
#  ('HTAN_HT168P1_S1H2_L1_L4_ROI_001',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HTAN_HT168P1_S1H2_L1_L4_ROI_001.ome.tiff'),
#  ('HTAN_HT122P1_S1H3_L1_L4_ROI_002',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HTAN_HT122P1_S1H3_L1_L4_ROI_002.ome.tiff'),
#  ('HTAN_HT124P1_S1H1_L1_L4_ROI_002',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HTAN_HT124P1_S1H1_L1_L4_ROI_002.ome.tiff'),
#  ('HTAN_HT166P1_S1H5_L4_ROI_002',
#   '../data/hyperion/b2_06252020_processed_10072021/ome-tiff/HTAN_HT166P1_S1H5_L4_ROI_002.ome.tiff')]

# %%
tif = TiffFile(sample_fp_tups[0][1])
m = re.sub(r'<Acquis.*AcquisitionDate>', r'', tif.ome_metadata)
ome = from_xml(m)
im = ome.images[0]
names = sorted({c.name for c in im.pixels.channels})
list(zip(names, [CHANNEL_MAP.get(parse_channel_name_from_raw(n), parse_channel_name_from_raw(n))
                 for n in names]))
# Out:
# [('100Ru', None),
#  ('101Ru', None),
#  ('102Ru', None),
#  ('104Ru', None),
#  ('113In', None),
#  ('115In', None),
#  ('127I', None),
#  ('131Xe', None),
#  ('138Ba', None),
#  ('139La', None),
#  ('141Pr-SMA', 'SMA'),
#  ('142Nd', None),
#  ('143Nd-Vimentin', 'Vimentin'),
#  ('144Nd', None),
#  ('145Nd', None),
#  ('146Nd', None),
#  ('147Sm-CD163', 'CD163'),
#  ('148Nd-PanK', 'Pan Keratin'),
#  ('149Sm-CD11b', 'CD11b'),
#  ('150Nd-PD-L1', 'PD-L1'),
#  ('151Eu-CD31', 'CD31'),
#  ('152Sm-CD45', 'CD45'),
#  ('153Eu-Lag3', 'Lag3'),
#  ('155Gd-FOXP3', 'FOXP3'),
#  ('156Gd-CD4', 'CD4'),
#  ('158Gd-Ecadherin', 'Ecadherin'),
#  ('159Tb-CD68', 'CD68'),
#  ('160Gd', None),
#  ('161Dy-CD20', 'CD20'),
#  ('162Dy-CD8a', 'CD8a'),
#  ('163Dy', None),
#  ('164Dy', None),
#  ('165Ho-PD1', 'PD-1'),
#  ('166Er-CD74', 'CD74'),
#  ('167Er-GranzymeB', 'Granzyme B'),
#  ('168Er-Ki67', 'Ki67'),
#  ('169Tm-Type1Coll', 'T1 Collagen'),
#  ('170Er-CD3', 'CD3'),
#  ('171Yb', None),
#  ('172Yb-', None),
#  ('173Yb-CD45RO', 'CD45RO'),
#  ('174Yb-HLA-DR', 'HLA-DR'),
#  ('175Lu-', None),
#  ('176YbHistoneH3', 'Histone H3'),
#  ('190BCKG', None),
#  ('191Ir-DNA', 'DNA'),
#  ('193Ir-DNA', 'DNA'),
#  ('208Pb', None),
#  ('209Bi', None),
#  ('89Y-', None),
#  ('Sm154-CD11c', 'CD11c')]

# %%
out_dir = f'../data/hyperion/{batch_folder}/ome-tiff_htan'
Path(out_dir).mkdir(exist_ok=True, parents=True)

# Out:
# Checking file format [OME-TIFF]
# Initializing reader
# OMETiffReader initializing ../data/hyperion/b2_06252020_processed_10072021/ome-tiff_htan/HTAN_HT122P1_S1H4_L1_L4_ROI_002.ome.tiff
# Reading IFDs
# Populating metadata
# PixelType mismatch: OME=6, TIFF=2
# Initialization took 0.102s
#
# Reading core metadata
# filename = /home/estorrs/imaging/notebooks/../data/hyperion/b2_06252020_processed_10072021/ome-tiff_htan/HTAN_HT122P1_S1H4_L1_L4_ROI_002.ome.tiff
# Used files = [/home/estorrs/imaging/notebooks/../data/hyperion/b2_06252020_processed_10072021/ome-tiff_htan/HTAN_HT122P1_S1H4_L1_L4_ROI_002.ome.tiff]
# Series count = 1
# Series #0 :
# 	Image count = 27
# 	RGB = false (1)
# 	Interleaved = false
# 	Indexed = false (false color)
# 	Width = 1015
# 	Height = 964
# 	SizeZ = 1
# 	SizeT = 1
# 	SizeC = 27
# 	Thumbnail size = 128 x 121
# 	Endianness = intel (little)
# 	Dimension order = XYCZT (certain)
# 	Pixel type = int16
# 	Valid bits per pixel = 16
# 	Metadata complete = true
# 	Thumbnail series = false
# 	-----
# 	Plane #0 <=> Z 0, C 0, T 0
# 	Plane #11 <=> Z 0, C 11, T 0
# 	Plane #12 <=> Z 0, C 12, T 0
# 	Plane #13 <=> Z 0, C 13, T 0
# 	Plane #14 <=> Z 0, C 14, T 0
# 	Plane #15 <=> Z 0, C 15, T 0
# 	Plane #26 <=> Z 0, C 26, T 0
#
#
# Reading global metadata
#
# Reading metadata

# %% [markdown]
# ## generate htan ome.tiffs from CODEX stiched folder

# %%
from ome_types import model

# %%
# fps = os_helpers.listfiles(f'/data/multiplex/codex_inhouse/codex/HT323B1/stiched/', regex=r'/stiched$')
# fps = [fp for fp in fps if 'HT056' in fp]
# sample_fp_tups = [(normalize_sample_name(fp.split('/')[-2]), fp) for fp in fps]
sample_fp_tups = [(batch_folder, f'/data/multiplex/codex_inhouse/codex/{batch_folder}/stiched/')]
sample_fp_tups
# Out:
# [('HT308B1-H5A4', '/data/multiplex/codex_inhouse/codex/HT308B1-H5A4/stiched/')]

# %%
out_dir = f'/data/multiplex/codex_inhouse/codex/{batch_folder}/ome_tiff/'
from pathlib import Path
Path(out_dir).mkdir(exist_ok=True, parents=True)

# %%
from ome_types import model
def stitched_to_ome(sample_id, fp, out_dir):
    """reads stitched tifs and returns ome.tiff with HTAN required metadata"""
    fps = sorted(os_helpers.listfiles(fp, regex='.tif$'))
    names = [fp.split('/')[-1].replace('.tif', '') for fp in fps]
    keep = [n for n in names if parse_codex_channel_name_from_raw(n) is not None]
    print(keep)
    keep_idxs = [i for i, n in enumerate(names) if parse_codex_channel_name_from_raw(n) is not None]
    new = [CHANNEL_MAP.get(parse_codex_channel_name_from_raw(n), parse_codex_channel_name_from_raw(n))
          for n in keep]
    name_to_identifier = {k:n for k, n in zip(keep, new)}
#     print(list(zip(keep, new)))
    
    x, y = None, None
    with tifffile.TiffWriter(out_fp, ome=True, bigtiff=True) as out_tif:
        for i, fp in enumerate(fps):
            if i in keep_idxs:
                img = tifffile.imread(fp)
                x, y = img.shape[1], img.shape[0]
                out_tif.write(img)
        o = model.OME()
        o.images.append(model.Image(id='Image:0', pixels=model.Pixels(dimension_order='XYCZT',
              size_c=len(keep_idxs),
              size_t=1,
              size_x=x,
              size_y=y,
              size_z=1,
              type='float',
              big_endian=False,
              channels=[model.Channel(id=f'Channel:{i}', name=f'{name_to_identifier[c]}') for i, c in enumerate(keep)],
              physical_size_x=float(x),
              physical_size_y=float(y),)))
        
        im = o.images[0]
        im.pixels.physical_size_x_unit = 'µm'
        im.pixels.physical_size_y_unit = 'µm'
        im.pixels.tiff_data_blocks.append(model.TiffData(plane_count=1))
        xml_str = to_xml(o)
        out_tif.overwrite_description(xml_str.encode())

# %%
import tifffile
for sample, fp in sample_fp_tups:
    print(sample)
    out_fp = os.path.join(out_dir, f'{sample}.ome.tiff')
    stitched_to_ome(sample, fp, out_fp)
# Out:
# HT308B1-H5A4
# ['reg001_cyc001_ch001_DAPI-01', 'reg001_cyc002_ch002_CD31', 'reg001_cyc002_ch003_E-cadherin', 'reg001_cyc002_ch004_CD4', 'reg001_cyc003_ch002_CD20', 'reg001_cyc003_ch003_Ki67', 'reg001_cyc003_ch004_CD68', 'reg001_cyc004_ch002_Pan-CK', 'reg001_cyc004_ch003_CD8', 'reg001_cyc004_ch004_Histone H3 Pho', 'reg001_cyc005_ch002_CD163', 'reg001_cyc005_ch003_Podoplanin', 'reg001_cyc005_ch004_CD3e', 'reg001_cyc006_ch002_beta-integrin', 'reg001_cyc006_ch003_HIF1a', 'reg001_cyc006_ch004_GLUT1', 'reg001_cyc007_ch002_GATA3', 'reg001_cyc007_ch003_CD45RO', 'reg001_cyc008_ch002_SMA', 'reg001_cyc008_ch004_MGP', 'reg001_cyc009_ch002_Vimentin', 'reg001_cyc009_ch003_Maspin', 'reg001_cyc009_ch004_Foxp3', 'reg001_cyc010_ch002_CK17', 'reg001_cyc010_ch003_MMP9', 'reg001_cyc010_ch004_HLA-DR', 'reg001_cyc011_ch002_CD36', 'reg001_cyc011_ch003_CK14', 'reg001_cyc011_ch004_CD11c', 'reg001_cyc012_ch002_cKit', 'reg001_cyc012_ch003_COX2', 'reg001_cyc012_ch004_GP2', 'reg001_cyc013_ch001_DAPI-13', 'reg001_cyc013_ch003_CD44']

# %% [markdown]
# ###### sandbox

# %%
tif = TiffFile('/data/multiplex/codex_inhouse/codex/HT323B1/ome_tiff/HT323B1.ome.tiff')
tif

# %%
tif.ome_metadata
# Out:
# '<OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd">\n    <Image ID="Image:0">\n        <Pixels BigEndian="false" DimensionOrder="XYCZT" ID="Pixels:1" PhysicalSizeX="21504.0" PhysicalSizeXUnit="µm" PhysicalSizeY="14112.0" PhysicalSizeYUnit="µm" SizeC="19" SizeT="1" SizeX="21504" SizeY="14112" SizeZ="1" Type="float">\n            <Channel ID="Channel:0" Name="CD31" />\n            <Channel ID="Channel:1" Name="E-cadherin" />\n            <Channel ID="Channel:2" Name="CD4" />\n            <Channel ID="Channel:3" Name="CD20" />\n            <Channel ID="Channel:4" Name="Ki67" />\n            <Channel ID="Channel:5" Name="CD68" />\n            <Channel ID="Channel:6" Name="Pan-CK" />\n            <Channel ID="Channel:7" Name="CD8" />\n            <Channel ID="Channel:8" Name="CD107a" />\n            <Channel ID="Channel:9" Name="GramzymB" />\n            <Channel ID="Channel:10" Name="Podoplanin" />\n            <Channel ID="Channel:11" Name="CD3" />\n            <Channel ID="Channel:12" Name="Vimentin" />\n            <Channel ID="Channel:13" Name="CD45RO" />\n            <Channel ID="Channel:14" Name="PDL-1" />\n            <Channel ID="Channel:15" Name="SMA" />\n            <Channel ID="Channel:16" Name="PD-1" />\n            <Channel ID="Channel:17" Name="CD45RA" />\n            <Channel ID="Channel:18" Name="CD11c" />\n            <TiffData PlaneCount="1" />\n        </Pixels>\n    </Image>\n</OME>'

# %%
p = tif.pages[0]
p

# %%
p.description
# Out:
# '<OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd">\n    <Image ID="Image:0">\n        <Pixels BigEndian="false" DimensionOrder="XYCZT" ID="Pixels:1" PhysicalSizeX="21504.0" PhysicalSizeXUnit="µm" PhysicalSizeY="14112.0" PhysicalSizeYUnit="µm" SizeC="19" SizeT="1" SizeX="21504" SizeY="14112" SizeZ="1" Type="float">\n            <Channel ID="Channel:0" Name="CD31" />\n            <Channel ID="Channel:1" Name="E-cadherin" />\n            <Channel ID="Channel:2" Name="CD4" />\n            <Channel ID="Channel:3" Name="CD20" />\n            <Channel ID="Channel:4" Name="Ki67" />\n            <Channel ID="Channel:5" Name="CD68" />\n            <Channel ID="Channel:6" Name="Pan-CK" />\n            <Channel ID="Channel:7" Name="CD8" />\n            <Channel ID="Channel:8" Name="CD107a" />\n            <Channel ID="Channel:9" Name="GramzymB" />\n            <Channel ID="Channel:10" Name="Podoplanin" />\n            <Channel ID="Channel:11" Name="CD3" />\n            <Channel ID="Channel:12" Name="Vimentin" />\n            <Channel ID="Channel:13" Name="CD45RO" />\n            <Channel ID="Channel:14" Name="PDL-1" />\n            <Channel ID="Channel:15" Name="SMA" />\n            <Channel ID="Channel:16" Name="PD-1" />\n            <Channel ID="Channel:17" Name="CD45RA" />\n            <Channel ID="Channel:18" Name="CD11c" />\n            <TiffData PlaneCount="1" />\n        </Pixels>\n    </Image>\n</OME>'

# %%
tif = TiffFile('../data/john_will_grant_imageing/S18_40270_C3_JH010721_roi2.ome.tiff')
m = re.sub(r'<Acquis.*AcquisitionDate>', r'', tif.ome_metadata)
m
# Out:
# '<?xml version=\'1.0\' encoding=\'UTF-8\'?>\n<OME Creator="imctools 2.1.0" xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd"><Image ID="Image:0" Name="S18_40270_C3_JH010721_roi2.ome.tiff"><Pixels BigEndian="false" DimensionOrder="XYCZT" ID="Pixels:0" Interleaved="true" SizeC="196" SizeT="1" SizeX="1349" SizeY="1371" SizeZ="1" Type="float"><Channel Fluor="As75" ID="Channel:0:0" Name="75As" SamplesPerPixel="1" /><Channel Fluor="Se76" ID="Channel:0:1" Name="76Se" SamplesPerPixel="1" /><Channel Fluor="Se77" ID="Channel:0:2" Name="77Se" SamplesPerPixel="1" /><Channel Fluor="Se78" ID="Channel:0:3" Name="78Se" SamplesPerPixel="1" /><Channel Fluor="Br79" ID="Channel:0:4" Name="79Br" SamplesPerPixel="1" /><Channel Fluor="ArAr80" ID="Channel:0:5" Name="80ArAr" SamplesPerPixel="1" /><Channel Fluor="Kr80" ID="Channel:0:6" Name="80Kr" SamplesPerPixel="1" /><Channel Fluor="Se80" ID="Channel:0:7" Name="80Se" SamplesPerPixel="1" /><Channel Fluor="Br81" ID="Channel:0:8" Name="81Br" SamplesPerPixel="1" /><Channel Fluor="Kr82" ID="Channel:0:9" Name="82Kr" SamplesPerPixel="1" /><Channel Fluor="Kr83" ID="Channel:0:10" Name="83Kr" SamplesPerPixel="1" /><Channel Fluor="Sr84" ID="Channel:0:11" Name="84Sr" SamplesPerPixel="1" /><Channel Fluor="Rb85" ID="Channel:0:12" Name="85Rb" SamplesPerPixel="1" /><Channel Fluor="Sr86" ID="Channel:0:13" Name="86Sr" SamplesPerPixel="1" /><Channel Fluor="Rb87" ID="Channel:0:14" Name="87Rb" SamplesPerPixel="1" /><Channel Fluor="Sr87" ID="Channel:0:15" Name="87Sr" SamplesPerPixel="1" /><Channel Fluor="Sr88" ID="Channel:0:16" Name="88Sr" SamplesPerPixel="1" /><Channel Fluor="Y89" ID="Channel:0:17" Name="89Y-" SamplesPerPixel="1" /><Channel Fluor="Zr90" ID="Channel:0:18" Name="90Zr" SamplesPerPixel="1" /><Channel Fluor="Zr91" ID="Channel:0:19" Name="91Zr" SamplesPerPixel="1" /><Channel Fluor="Mo92" ID="Channel:0:20" Name="92Mo" SamplesPerPixel="1" /><Channel Fluor="Zr92" ID="Channel:0:21" Name="92Zr" SamplesPerPixel="1" /><Channel Fluor="Nb93" ID="Channel:0:22" Name="93Nb" SamplesPerPixel="1" /><Channel Fluor="Mo94" ID="Channel:0:23" Name="94Mo" SamplesPerPixel="1" /><Channel Fluor="Zr94" ID="Channel:0:24" Name="94Zr" SamplesPerPixel="1" /><Channel Fluor="Mo95" ID="Channel:0:25" Name="95Mo" SamplesPerPixel="1" /><Channel Fluor="Mo96" ID="Channel:0:26" Name="96Mo" SamplesPerPixel="1" /><Channel Fluor="Ru96" ID="Channel:0:27" Name="96Ru" SamplesPerPixel="1" /><Channel Fluor="Zr96" ID="Channel:0:28" Name="96Zr" SamplesPerPixel="1" /><Channel Fluor="Mo97" ID="Channel:0:29" Name="97Mo" SamplesPerPixel="1" /><Channel Fluor="Mo98" ID="Channel:0:30" Name="98Mo" SamplesPerPixel="1" /><Channel Fluor="Ru98" ID="Channel:0:31" Name="98Ru" SamplesPerPixel="1" /><Channel Fluor="Ru99" ID="Channel:0:32" Name="99Ru" SamplesPerPixel="1" /><Channel Fluor="Mo100" ID="Channel:0:33" Name="100Mo" SamplesPerPixel="1" /><Channel Fluor="Ru100" ID="Channel:0:34" Name="100Ru" SamplesPerPixel="1" /><Channel Fluor="Ru101" ID="Channel:0:35" Name="101Ru" SamplesPerPixel="1" /><Channel Fluor="Pd102" ID="Channel:0:36" Name="102Pd" SamplesPerPixel="1" /><Channel Fluor="Ru102" ID="Channel:0:37" Name="102Ru" SamplesPerPixel="1" /><Channel Fluor="Rh103" ID="Channel:0:38" Name="103Rh" SamplesPerPixel="1" /><Channel Fluor="Pd104" ID="Channel:0:39" Name="104Pd" SamplesPerPixel="1" /><Channel Fluor="Ru104" ID="Channel:0:40" Name="104Ru" SamplesPerPixel="1" /><Channel Fluor="Pd105" ID="Channel:0:41" Name="105Pd" SamplesPerPixel="1" /><Channel Fluor="Cd106" ID="Channel:0:42" Name="106Cd" SamplesPerPixel="1" /><Channel Fluor="Pd106" ID="Channel:0:43" Name="106Pd" SamplesPerPixel="1" /><Channel Fluor="Ag107" ID="Channel:0:44" Name="107Ag" SamplesPerPixel="1" /><Channel Fluor="Cd108" ID="Channel:0:45" Name="108Cd" SamplesPerPixel="1" /><Channel Fluor="Pd108" ID="Channel:0:46" Name ...

# %%
from ome_types import from_tiff, from_xml, to_xml
from ome_types.model.simple_types import UnitsLength

d = {
    'Vimentin': ['vimentin'],
    'PanKeratin': ['PanCK'],
    'PD-L1': ['PDL1'],
    'PD-1': ['PD1']
}
CHANNEL_MAP = {v:k for k, vs in d.items() for v in vs}

def convert_hyperion_ome_to_htan_ome(fp, out_fp):
    tif = TiffFile(fp)
    m = re.sub(r'<Acquis.*AcquisitionDate>', r'', tif.ome_metadata)
    ome = from_xml(m)
    im = ome.images[0]
    im.pixels.physical_size_x = float(im.pixels.size_x)
    im.pixels.physical_size_y = float(im.pixels.size_y)
    im.pixels.physical_size_x_unit = 'µm'
    im.pixels.physical_size_y_unit = 'µm'
    im.pixels.tiff_data_blocks[0].plane_count = 1
    im.pixels.type = 'float'
    
    names = sorted({c.name for c in im.pixels.channels})
    keep = [n for n in names if '-' in n if re.sub(r'^[^-]*-(.*)$', r'\1', n)]
    keep_idxs = [i for i, n in enumerate(names) if '-' in n if re.sub(r'^[^-]*-(.*)$', r'\1', n)]
    new = [CHANNEL_MAP.get(re.sub(r'^[^-]*-(.*)$', r'\1', n), re.sub(r'^[^-]*-(.*)$', r'\1', n))
          for n in keep]
    name_to_identifier = {k:n for k, n in zip(keep, new)}
#     p(zip(keep, new))
    im.pixels.channels = [c for c in im.pixels.channels if c.name in keep]
    for c in im.pixels.channels: c.name = name_to_identifier[c.name]
        
    xml_str = to_xml(ome)
    with tifffile.TiffWriter(out_fp, ome=True) as out_tif:
        for i, p in enumerate(tif.pages):
            if i in keep_idxs:
                out_tif.write(p.asarray())
        out_tif.overwrite_description(xml_str.encode())

# %%
t = from_xml(m)
t
# Out:
# OME(
#    creator='imctools 2.1.0',
#    images=[<1 Images>],
# )

# %%
im = t.images[0]
im
# Out:
# Image(
#    id='Image:0',
#    name='S18_40270_C3_JH010721_roi2.ome.tiff',
#    pixels=Pixels(
#       id='Pixels:0',
#       dimension_order='XYCZT',
#       size_c=196,
#       size_t=1,
#       size_x=1349,
#       size_y=1371,
#       size_z=1,
#       type='float',
#       big_endian=False,
#       channels=[<196 Channels>],
#       interleaved=True,
#       tiff_data_blocks=[<1 Tiff_Data_Blocks>],
#    ),
# )

# %%
im.pixels.physical_size_x = float(im.pixels.size_x)
im.pixels.physical_size_y = float(im.pixels.size_y)
im.pixels.physical_size_x_unit = 'µm'
im.pixels.physical_size_y_unit = 'µm'
im.pixels.tiff_data_blocks[0].plane_count = 1
im.pixels.type = 'float'
im
# Out:
# Image(
#    id='Image:0',
#    name='S18_40270_C3_JH010721_roi2.ome.tiff',
#    pixels=Pixels(
#       id='Pixels:0',
#       dimension_order='XYCZT',
#       size_c=196,
#       size_t=1,
#       size_x=1349,
#       size_y=1371,
#       size_z=1,
#       type='float',
#       big_endian=False,
#       channels=[<196 Channels>],
#       interleaved=True,
#       physical_size_x=1349.0,
#       physical_size_x_unit='µm',
#       physical_size_y=1371.0,
#       physical_size_y_unit='µm',
#       tiff_data_blocks=[<1 Tiff_Data_Blocks>],
#    ),
# )

# %%
for c in im.pixels.channels:
    print(c)
# Out:
# Channel(
#    id='Channel:0:0',
#    name='75As',
#    fluor='As75',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:1',
#    name='76Se',
#    fluor='Se76',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:2',
#    name='77Se',
#    fluor='Se77',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:3',
#    name='78Se',
#    fluor='Se78',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:4',
#    name='79Br',
#    fluor='Br79',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:5',
#    name='80ArAr',
#    fluor='ArAr80',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:6',
#    name='80Kr',
#    fluor='Kr80',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:7',
#    name='80Se',
#    fluor='Se80',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:8',
#    name='81Br',
#    fluor='Br81',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:9',
#    name='82Kr',
#    fluor='Kr82',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:10',
#    name='83Kr',
#    fluor='Kr83',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:11',
#    name='84Sr',
#    fluor='Sr84',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:12',
#    name='85Rb',
#    fluor='Rb85',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:13',
#    name='86Sr',
#    fluor='Sr86',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:14',
#    name='87Rb',
#    fluor='Rb87',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:15',
#    name='87Sr',
#    fluor='Sr87',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:16',
#    name='88Sr',
#    fluor='Sr88',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:17',
#    name='89Y-',
#    fluor='Y89',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:18',
#    name='90Zr',
#    fluor='Zr90',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:19',
#    name='91Zr',
#    fluor='Zr91',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:20',
#    name='92Mo',
#    fluor='Mo92',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:21',
#    name='92Zr',
#    fluor='Zr92',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:22',
#    name='93Nb',
#    fluor='Nb93',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:23',
#    name='94Mo',
#    fluor='Mo94',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:24',
#    name='94Zr',
#    fluor='Zr94',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:25',
#    name='95Mo',
#    fluor='Mo95',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:26',
#    name='96Mo',
#    fluor='Mo96',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:27',
#    name='96Ru',
#    fluor='Ru96',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:28',
#    name='96Zr',
#    fluor='Zr96',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:29',
#    name='97Mo',
#    fluor='Mo97',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:30',
#    name='98Mo',
#    fluor='Mo98',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:31',
#    name='98Ru',
#    fluor='Ru98',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:32',
#    name='99Ru',
#    fluor='Ru99',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:33',
#    name='100Mo',
#    fluor='Mo100',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:34',
#    name='100Ru',
#    fluor='Ru100',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:35',
#    name='101Ru',
#    fluor='Ru101',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:36',
#    name='102Pd',
#    fluor='Pd102',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:37',
#    name='102Ru',
#    fluor='Ru102',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:38',
#    name='103Rh',
#    fluor='Rh103',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:39',
#    name='104Pd',
#    fluor='Pd104',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:40',
#    name='104Ru',
#    fluor='Ru104',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:41',
#    name='105Pd',
#    fluor='Pd105',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:42',
#    name='106Cd',
#    fluor='Cd106',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:43',
#    name='106Pd',
#    fluor='Pd106',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:44',
#    name='107Ag',
#    fluor='Ag107',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:45',
#    name='108Cd',
#    fluor='Cd108',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:46',
#    name='108Pd',
#    fluor='Pd108',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:47',
#    name='109Ag',
#    fluor='Ag109',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:48',
#    name='110Cd',
#    fluor='Cd110',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:49',
#    name='110Pd',
#    fluor='Pd110',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:50',
#    name='111Cd',
#    fluor='Cd111',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:51',
#    name='112Cd',
#    fluor='Cd112',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:52',
#    name='112Sn',
#    fluor='Sn112',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:53',
#    name='113Cd',
#    fluor='Cd113',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:54',
#    name='113In',
#    fluor='In113',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:55',
#    name='114Cd',
#    fluor='Cd114',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:56',
#    name='114Sn',
#    fluor='Sn114',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:57',
#    name='115In-',
#    fluor='In115',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:58',
#    name='115Sn',
#    fluor='Sn115',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:59',
#    name='116Cd',
#    fluor='Cd116',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:60',
#    name='116Sn',
#    fluor='Sn116',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:61',
#    name='117Sn',
#    fluor='Sn117',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:62',
#    name='118Sn',
#    fluor='Sn118',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:63',
#    name='119Sn',
#    fluor='Sn119',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:64',
#    name='120Sn',
#    fluor='Sn120',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:65',
#    name='120Te',
#    fluor='Te120',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:66',
#    name='121Sb',
#    fluor='Sb121',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:67',
#    name='122Sn',
#    fluor='Sn122',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:68',
#    name='122Te',
#    fluor='Te122',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:69',
#    name='123Sb',
#    fluor='Sb123',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:70',
#    name='123Te',
#    fluor='Te123',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:71',
#    name='124Sn',
#    fluor='Sn124',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:72',
#    name='124Te',
#    fluor='Te124',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:73',
#    name='124Xe',
#    fluor='Xe124',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:74',
#    name='125Te',
#    fluor='Te125',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:75',
#    name='126Te',
#    fluor='Te126',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:76',
#    name='126Xe',
#    fluor='Xe126',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:77',
#    name='127I',
#    fluor='I127',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:78',
#    name='128Te',
#    fluor='Te128',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:79',
#    name='128Xe',
#    fluor='Xe128',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:80',
#    name='129Xe',
#    fluor='Xe129',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:81',
#    name='130Ba',
#    fluor='Ba130',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:82',
#    name='130Te',
#    fluor='Te130',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:83',
#    name='130Xe',
#    fluor='Xe130',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:84',
#    name='131Xe',
#    fluor='Xe131',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:85',
#    name='132Ba',
#    fluor='Ba132',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:86',
#    name='132Xe',
#    fluor='Xe132',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:87',
#    name='133Cs',
#    fluor='Cs133',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:88',
#    name='134Ba',
#    fluor='Ba134',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:89',
#    name='134Xe',
#    fluor='Xe134',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:90',
#    name='135Ba',
#    fluor='Ba135',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:91',
#    name='136Ba',
#    fluor='Ba136',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:92',
#    name='136Ce',
#    fluor='Ce136',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:93',
#    name='136Xe',
#    fluor='Xe136',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:94',
#    name='137Ba',
#    fluor='Ba137',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:95',
#    name='138Ba',
#    fluor='Ba138',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:96',
#    name='138Ce',
#    fluor='Ce138',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:97',
#    name='138La',
#    fluor='La138',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:98',
#    name='139La-',
#    fluor='La139',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:99',
#    name='140Ce',
#    fluor='Ce140',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:100',
#    name='141Pr-SMA',
#    fluor='Pr141',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:101',
#    name='142Ce',
#    fluor='Ce142',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:102',
#    name='142Nd-',
#    fluor='Nd142',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:103',
#    name='143Nd-vimentin',
#    fluor='Nd143',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:104',
#    name='144Nd-',
#    fluor='Nd144',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:105',
#    name='144Sm',
#    fluor='Sm144',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:106',
#    name='145Nd-',
#    fluor='Nd145',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:107',
#    name='146Nd-',
#    fluor='Nd146',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:108',
#    name='147Sm-',
#    fluor='Sm147',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:109',
#    name='148Nd-PanCK',
#    fluor='Nd148',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:110',
#    name='148Sm',
#    fluor='Sm148',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:111',
#    name='149Sm-',
#    fluor='Sm149',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:112',
#    name='150Nd-PDL1',
#    fluor='Nd150',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:113',
#    name='150Sm-',
#    fluor='Sm150',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:114',
#    name='151Eu-',
#    fluor='Eu151',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:115',
#    name='152Gd',
#    fluor='Gd152',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:116',
#    name='152Sm-',
#    fluor='Sm152',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:117',
#    name='153Eu-',
#    fluor='Eu153',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:118',
#    name='154Gd',
#    fluor='Gd154',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:119',
#    name='Sm154-',
#    fluor='Sm154',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:120',
#    name='155Gd-FOXP3',
#    fluor='Gd155',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:121',
#    name='156Dy',
#    fluor='Dy156',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:122',
#    name='156Gd-CD4',
#    fluor='Gd156',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:123',
#    name='157Gd-',
#    fluor='Gd157',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:124',
#    name='158Dy',
#    fluor='Dy158',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:125',
#    name='158Gd-Ecadherin',
#    fluor='Gd158',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:126',
#    name='159Tb-CD68',
#    fluor='Tb159',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:127',
#    name='160Dy',
#    fluor='Dy160',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:128',
#    name='160Gd-',
#    fluor='Gd160',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:129',
#    name='161Dy-CD20',
#    fluor='Dy161',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:130',
#    name='162Dy-CD8a',
#    fluor='Dy162',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:131',
#    name='162Er',
#    fluor='Er162',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:132',
#    name='163Dy-',
#    fluor='Dy163',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:133',
#    name='164Dy-',
#    fluor='Dy164',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:134',
#    name='164Er',
#    fluor='Er164',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:135',
#    name='165Ho-PD1',
#    fluor='Ho165',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:136',
#    name='166Er-',
#    fluor='Er166',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:137',
#    name='167Er-GranzymeB',
#    fluor='Er167',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:138',
#    name='168Er-Ki67',
#    fluor='Er168',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:139',
#    name='168Yb',
#    fluor='Yb168',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:140',
#    name='169Tm-CollagenT1',
#    fluor='Tm169',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:141',
#    name='170Er-CD3',
#    fluor='Er170',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:142',
#    name='170Yb',
#    fluor='Yb170',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:143',
#    name='171Yb-',
#    fluor='Yb171',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:144',
#    name='172Yb-',
#    fluor='Yb172',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:145',
#    name='173Yb-CD45RO',
#    fluor='Yb173',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:146',
#    name='174Hf',
#    fluor='Hf174',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:147',
#    name='174Yb-',
#    fluor='Yb174',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:148',
#    name='175Lu-',
#    fluor='Lu175',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:149',
#    name='176Hf',
#    fluor='Hf176',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:150',
#    name='176Lu',
#    fluor='Lu176',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:151',
#    name='176Yb-HistoneH3',
#    fluor='Yb176',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:152',
#    name='177Hf',
#    fluor='Hf177',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:153',
#    name='178Hf',
#    fluor='Hf178',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:154',
#    name='179Hf',
#    fluor='Hf179',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:155',
#    name='180Hf',
#    fluor='Hf180',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:156',
#    name='180Ta',
#    fluor='Ta180',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:157',
#    name='180W',
#    fluor='W180',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:158',
#    name='181Ta',
#    fluor='Ta181',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:159',
#    name='182W',
#    fluor='W182',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:160',
#    name='183W',
#    fluor='W183',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:161',
#    name='184Os',
#    fluor='Os184',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:162',
#    name='184W',
#    fluor='W184',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:163',
#    name='185Re',
#    fluor='Re185',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:164',
#    name='186Os',
#    fluor='Os186',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:165',
#    name='186W',
#    fluor='W186',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:166',
#    name='187Os',
#    fluor='Os187',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:167',
#    name='187Re',
#    fluor='Re187',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:168',
#    name='188Os',
#    fluor='Os188',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:169',
#    name='189Os',
#    fluor='Os189',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:170',
#    name='190BCKG',
#    fluor='BCKG190',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:171',
#    name='190Os',
#    fluor='Os190',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:172',
#    name='190Pt',
#    fluor='Pt190',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:173',
#    name='191Ir-DNA1',
#    fluor='Ir191',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:174',
#    name='192Os',
#    fluor='Os192',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:175',
#    name='192Pt',
#    fluor='Pt192',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:176',
#    name='193Ir-DNA2',
#    fluor='Ir193',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:177',
#    name='194Pt',
#    fluor='Pt194',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:178',
#    name='195Pt-cellseg1',
#    fluor='Pt195',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:179',
#    name='196Hg',
#    fluor='Hg196',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:180',
#    name='196Pt-cellseg2',
#    fluor='Pt196',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:181',
#    name='197Au',
#    fluor='Au197',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:182',
#    name='198Hg',
#    fluor='Hg198',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:183',
#    name='198Pt-cellseg3',
#    fluor='Pt198',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:184',
#    name='199Hg',
#    fluor='Hg199',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:185',
#    name='200Hg',
#    fluor='Hg200',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:186',
#    name='201Hg',
#    fluor='Hg201',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:187',
#    name='202Hg',
#    fluor='Hg202',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:188',
#    name='203Tl',
#    fluor='Tl203',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:189',
#    name='204Hg',
#    fluor='Hg204',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:190',
#    name='204Pb',
#    fluor='Pb204',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:191',
#    name='205Tl',
#    fluor='Tl205',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:192',
#    name='206Pb',
#    fluor='Pb206',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:193',
#    name='207Pb',
#    fluor='Pb207',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:194',
#    name='208Pb',
#    fluor='Pb208',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:195',
#    name='209Bi-',
#    fluor='Bi209',
#    samples_per_pixel=1,
# )

# %%
names = sorted({c.name for c in im.pixels.channels})
names
# Out:
# ['100Mo',
#  '100Ru',
#  '101Ru',
#  '102Pd',
#  '102Ru',
#  '103Rh',
#  '104Pd',
#  '104Ru',
#  '105Pd',
#  '106Cd',
#  '106Pd',
#  '107Ag',
#  '108Cd',
#  '108Pd',
#  '109Ag',
#  '110Cd',
#  '110Pd',
#  '111Cd',
#  '112Cd',
#  '112Sn',
#  '113Cd',
#  '113In',
#  '114Cd',
#  '114Sn',
#  '115In-',
#  '115Sn',
#  '116Cd',
#  '116Sn',
#  '117Sn',
#  '118Sn',
#  '119Sn',
#  '120Sn',
#  '120Te',
#  '121Sb',
#  '122Sn',
#  '122Te',
#  '123Sb',
#  '123Te',
#  '124Sn',
#  '124Te',
#  '124Xe',
#  '125Te',
#  '126Te',
#  '126Xe',
#  '127I',
#  '128Te',
#  '128Xe',
#  '129Xe',
#  '130Ba',
#  '130Te',
#  '130Xe',
#  '131Xe',
#  '132Ba',
#  '132Xe',
#  '133Cs',
#  '134Ba',
#  '134Xe',
#  '135Ba',
#  '136Ba',
#  '136Ce',
#  '136Xe',
#  '137Ba',
#  '138Ba',
#  '138Ce',
#  '138La',
#  '139La-',
#  '140Ce',
#  '141Pr-SMA',
#  '142Ce',
#  '142Nd-',
#  '143Nd-vimentin',
#  '144Nd-',
#  '144Sm',
#  '145Nd-',
#  '146Nd-',
#  '147Sm-',
#  '148Nd-PanCK',
#  '148Sm',
#  '149Sm-',
#  '150Nd-PDL1',
#  '150Sm-',
#  '151Eu-',
#  '152Gd',
#  '152Sm-',
#  '153Eu-',
#  '154Gd',
#  '155Gd-FOXP3',
#  '156Dy',
#  '156Gd-CD4',
#  '157Gd-',
#  '158Dy',
#  '158Gd-Ecadherin',
#  '159Tb-CD68',
#  '160Dy',
#  '160Gd-',
#  '161Dy-CD20',
#  '162Dy-CD8a',
#  '162Er',
#  '163Dy-',
#  '164Dy-',
#  '164Er',
#  '165Ho-PD1',
#  '166Er-',
#  '167Er-GranzymeB',
#  '168Er-Ki67',
#  '168Yb',
#  '169Tm-CollagenT1',
#  '170Er-CD3',
#  '170Yb',
#  '171Yb-',
#  '172Yb-',
#  '173Yb-CD45RO',
#  '174Hf',
#  '174Yb-',
#  '175Lu-',
#  '176Hf',
#  '176Lu',
#  '176Yb-HistoneH3',
#  '177Hf',
#  '178Hf',
#  '179Hf',
#  '180Hf',
#  '180Ta',
#  '180W',
#  '181Ta',
#  '182W',
#  '183W',
#  '184Os',
#  '184W',
#  '185Re',
#  '186Os',
#  '186W',
#  '187Os',
#  '187Re',
#  '188Os',
#  '189Os',
#  '190BCKG',
#  '190Os',
#  '190Pt',
#  '191Ir-DNA1',
#  '192Os',
#  '192Pt',
#  '193Ir-DNA2',
#  '194Pt',
#  '195Pt-cellseg1',
#  '196Hg',
#  '196Pt-cellseg2',
#  '197Au',
#  '198Hg',
#  '198Pt-cellseg3',
#  '199Hg',
#  '200Hg',
#  '201Hg',
#  '202Hg',
#  '203Tl',
#  '204Hg',
#  '204Pb',
#  '205Tl',
#  '206Pb',
#  '207Pb',
#  '208Pb',
#  '209Bi-',
#  '75As',
#  '76Se',
#  '77Se',
#  '78Se',
#  '79Br',
#  '80ArAr',
#  '80Kr',
#  '80Se',
#  '81Br',
#  '82Kr',
#  '83Kr',
#  '84Sr',
#  '85Rb',
#  '86Sr',
#  '87Rb',
#  '87Sr',
#  '88Sr',
#  '89Y-',
#  '90Zr',
#  '91Zr',
#  '92Mo',
#  '92Zr',
#  '93Nb',
#  '94Mo',
#  '94Zr',
#  '95Mo',
#  '96Mo',
#  '96Ru',
#  '96Zr',
#  '97Mo',
#  '98Mo',
#  '98Ru',
#  '99Ru',
#  'Sm154-']

# %%
d = {
    'Vimentin': ['vimentin'],
    'PanKeratin': ['PanCK'],
    'PD-L1': ['PDL1'],
    'PD-1': ['PD1']
}
CHANNEL_MAP = {v:k for k, vs in d.items() for v in vs}

# %%
keep = [n for n in names if '-' in n if re.sub(r'^[^-]*-(.*)$', r'\1', n)]
keep_idxs = [i for i, n in enumerate(names) if '-' in n if re.sub(r'^[^-]*-(.*)$', r'\1', n)]
new = [CHANNEL_MAP.get(re.sub(r'^[^-]*-(.*)$', r'\1', n), re.sub(r'^[^-]*-(.*)$', r'\1', n))
      for n in keep]
name_to_identifier = {k:n for k, n in zip(keep, new)}
list(zip(keep, new))
# Out:
# [('141Pr-SMA', 'SMA'),
#  ('143Nd-vimentin', 'Vimentin'),
#  ('148Nd-PanCK', 'PanKeratin'),
#  ('150Nd-PDL1', 'PD-L1'),
#  ('155Gd-FOXP3', 'FOXP3'),
#  ('156Gd-CD4', 'CD4'),
#  ('158Gd-Ecadherin', 'Ecadherin'),
#  ('159Tb-CD68', 'CD68'),
#  ('161Dy-CD20', 'CD20'),
#  ('162Dy-CD8a', 'CD8a'),
#  ('165Ho-PD1', 'PD-1'),
#  ('167Er-GranzymeB', 'GranzymeB'),
#  ('168Er-Ki67', 'Ki67'),
#  ('169Tm-CollagenT1', 'CollagenT1'),
#  ('170Er-CD3', 'CD3'),
#  ('173Yb-CD45RO', 'CD45RO'),
#  ('176Yb-HistoneH3', 'HistoneH3'),
#  ('191Ir-DNA1', 'DNA1'),
#  ('193Ir-DNA2', 'DNA2'),
#  ('195Pt-cellseg1', 'cellseg1'),
#  ('196Pt-cellseg2', 'cellseg2'),
#  ('198Pt-cellseg3', 'cellseg3')]

# %%
im.pixels.channels = [c for c in im.pixels.channels if c.name in keep]
for c in im.pixels.channels: c.name = name_to_identifier[c.name]
for c in im.pixels.channels: print(c)
# Out:
# Channel(
#    id='Channel:0:100',
#    name='SMA',
#    fluor='Pr141',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:103',
#    name='Vimentin',
#    fluor='Nd143',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:109',
#    name='PanKeratin',
#    fluor='Nd148',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:112',
#    name='PD-L1',
#    fluor='Nd150',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:120',
#    name='FOXP3',
#    fluor='Gd155',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:122',
#    name='CD4',
#    fluor='Gd156',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:125',
#    name='Ecadherin',
#    fluor='Gd158',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:126',
#    name='CD68',
#    fluor='Tb159',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:129',
#    name='CD20',
#    fluor='Dy161',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:130',
#    name='CD8a',
#    fluor='Dy162',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:135',
#    name='PD-1',
#    fluor='Ho165',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:137',
#    name='GranzymeB',
#    fluor='Er167',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:138',
#    name='Ki67',
#    fluor='Er168',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:140',
#    name='CollagenT1',
#    fluor='Tm169',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:141',
#    name='CD3',
#    fluor='Er170',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:145',
#    name='CD45RO',
#    fluor='Yb173',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:151',
#    name='HistoneH3',
#    fluor='Yb176',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:173',
#    name='DNA1',
#    fluor='Ir191',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:176',
#    name='DNA2',
#    fluor='Ir193',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:178',
#    name='cellseg1',
#    fluor='Pt195',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:180',
#    name='cellseg2',
#    fluor='Pt196',
#    samples_per_pixel=1,
# )
# Channel(
#    id='Channel:0:183',
#    name='cellseg3',
#    fluor='Pt198',
#    samples_per_pixel=1,
# )

# %%
xml_str = to_xml(t)
xml_str
# Out:
# '<OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" Creator="imctools 2.1.0" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd">\n    <Image ID="Image:0" Name="S18_40270_C3_JH010721_roi2.ome.tiff">\n        <Pixels BigEndian="false" DimensionOrder="XYCZT" ID="Pixels:0" Interleaved="true" PhysicalSizeX="1349.0" PhysicalSizeXUnit="µm" PhysicalSizeY="1371.0" PhysicalSizeYUnit="µm" SizeC="196" SizeT="1" SizeX="1349" SizeY="1371" SizeZ="1" Type="float">\n            <Channel Fluor="Pr141" ID="Channel:0:100" Name="SMA" SamplesPerPixel="1" />\n            <Channel Fluor="Nd143" ID="Channel:0:103" Name="Vimentin" SamplesPerPixel="1" />\n            <Channel Fluor="Nd148" ID="Channel:0:109" Name="PanKeratin" SamplesPerPixel="1" />\n            <Channel Fluor="Nd150" ID="Channel:0:112" Name="PD-L1" SamplesPerPixel="1" />\n            <Channel Fluor="Gd155" ID="Channel:0:120" Name="FOXP3" SamplesPerPixel="1" />\n            <Channel Fluor="Gd156" ID="Channel:0:122" Name="CD4" SamplesPerPixel="1" />\n            <Channel Fluor="Gd158" ID="Channel:0:125" Name="Ecadherin" SamplesPerPixel="1" />\n            <Channel Fluor="Tb159" ID="Channel:0:126" Name="CD68" SamplesPerPixel="1" />\n            <Channel Fluor="Dy161" ID="Channel:0:129" Name="CD20" SamplesPerPixel="1" />\n            <Channel Fluor="Dy162" ID="Channel:0:130" Name="CD8a" SamplesPerPixel="1" />\n            <Channel Fluor="Ho165" ID="Channel:0:135" Name="PD-1" SamplesPerPixel="1" />\n            <Channel Fluor="Er167" ID="Channel:0:137" Name="GranzymeB" SamplesPerPixel="1" />\n            <Channel Fluor="Er168" ID="Channel:0:138" Name="Ki67" SamplesPerPixel="1" />\n            <Channel Fluor="Tm169" ID="Channel:0:140" Name="CollagenT1" SamplesPerPixel="1" />\n            <Channel Fluor="Er170" ID="Channel:0:141" Name="CD3" SamplesPerPixel="1" />\n            <Channel Fluor="Yb173" ID="Channel:0:145" Name="CD45RO" SamplesPerPixel="1" />\n            <Channel Fluor="Yb176" ID="Channel:0:151" Name="HistoneH3" SamplesPerPixel="1" />\n            <Channel Fluor="Ir191" ID="Channel:0:173" Name="DNA1" SamplesPerPixel="1" />\n            <Channel Fluor="Ir193" ID="Channel:0:176" Name="DNA2" SamplesPerPixel="1" />\n            <Channel Fluor="Pt195" ID="Channel:0:178" Name="cellseg1" SamplesPerPixel="1" />\n            <Channel Fluor="Pt196" ID="Channel:0:180" Name="cellseg2" SamplesPerPixel="1" />\n            <Channel Fluor="Pt198" ID="Channel:0:183" Name="cellseg3" SamplesPerPixel="1" />\n            <TiffData PlaneCount="1" />\n        </Pixels>\n    </Image>\n</OME>\n'

# %%
with tifffile.TiffWriter('../data/test3.ome.tiff', ome=True) as out_tif:
    for i, p in enumerate(tif.pages):
        if i in keep_idxs:
            out_tif.write(p.asarray())
    out_tif.overwrite_description(xml_str.encode())

# %%
h = from_tiff('../data/test3.ome.tiff')
h
# Out:
# OME(
#    creator='imctools 2.1.0',
#    images=[<1 Images>],
# )

# %%
h.images[0]
# Out:
# Image(
#    id='Image:0',
#    name='S18_40270_C3_JH010721_roi2.ome.tiff',
#    pixels=Pixels(
#       id='Pixels:0',
#       dimension_order='XYCZT',
#       size_c=196,
#       size_t=1,
#       size_x=1349,
#       size_y=1371,
#       size_z=1,
#       type='float',
#       big_endian=False,
#       channels=[<22 Channels>],
#       interleaved=True,
#       physical_size_x=1349.0,
#       physical_size_y=1371.0,
#       tiff_data_blocks=[<1 Tiff_Data_Blocks>],
#    ),
# )

# %%
h = tifffile.TiffFile('../data/test3.ome.tiff').ome_metadata
h
# Out:
# '<OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" Creator="imctools 2.1.0" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd">\n    <Image ID="Image:0" Name="S18_40270_C3_JH010721_roi2.ome.tiff">\n        <Pixels BigEndian="false" DimensionOrder="XYCZT" ID="Pixels:0" Interleaved="true" PhysicalSizeX="1349.0" PhysicalSizeXUnit="µm" PhysicalSizeY="1371.0" PhysicalSizeYUnit="µm" SizeC="196" SizeT="1" SizeX="1349" SizeY="1371" SizeZ="1" Type="float">\n            <Channel Fluor="Pr141" ID="Channel:0:100" Name="SMA" SamplesPerPixel="1" />\n            <Channel Fluor="Nd143" ID="Channel:0:103" Name="Vimentin" SamplesPerPixel="1" />\n            <Channel Fluor="Nd148" ID="Channel:0:109" Name="PanKeratin" SamplesPerPixel="1" />\n            <Channel Fluor="Nd150" ID="Channel:0:112" Name="PD-L1" SamplesPerPixel="1" />\n            <Channel Fluor="Gd155" ID="Channel:0:120" Name="FOXP3" SamplesPerPixel="1" />\n            <Channel Fluor="Gd156" ID="Channel:0:122" Name="CD4" SamplesPerPixel="1" />\n            <Channel Fluor="Gd158" ID="Channel:0:125" Name="Ecadherin" SamplesPerPixel="1" />\n            <Channel Fluor="Tb159" ID="Channel:0:126" Name="CD68" SamplesPerPixel="1" />\n            <Channel Fluor="Dy161" ID="Channel:0:129" Name="CD20" SamplesPerPixel="1" />\n            <Channel Fluor="Dy162" ID="Channel:0:130" Name="CD8a" SamplesPerPixel="1" />\n            <Channel Fluor="Ho165" ID="Channel:0:135" Name="PD-1" SamplesPerPixel="1" />\n            <Channel Fluor="Er167" ID="Channel:0:137" Name="GranzymeB" SamplesPerPixel="1" />\n            <Channel Fluor="Er168" ID="Channel:0:138" Name="Ki67" SamplesPerPixel="1" />\n            <Channel Fluor="Tm169" ID="Channel:0:140" Name="CollagenT1" SamplesPerPixel="1" />\n            <Channel Fluor="Er170" ID="Channel:0:141" Name="CD3" SamplesPerPixel="1" />\n            <Channel Fluor="Yb173" ID="Channel:0:145" Name="CD45RO" SamplesPerPixel="1" />\n            <Channel Fluor="Yb176" ID="Channel:0:151" Name="HistoneH3" SamplesPerPixel="1" />\n            <Channel Fluor="Ir191" ID="Channel:0:173" Name="DNA1" SamplesPerPixel="1" />\n            <Channel Fluor="Ir193" ID="Channel:0:176" Name="DNA2" SamplesPerPixel="1" />\n            <Channel Fluor="Pt195" ID="Channel:0:178" Name="cellseg1" SamplesPerPixel="1" />\n            <Channel Fluor="Pt196" ID="Channel:0:180" Name="cellseg2" SamplesPerPixel="1" />\n            <Channel Fluor="Pt198" ID="Channel:0:183" Name="cellseg3" SamplesPerPixel="1" />\n            <TiffData PlaneCount="1" />\n        </Pixels>\n    </Image>\n</OME>'

# %%
tif = TiffFile('../data/test3.ome.tiff')
tif.ome_metadata
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd" UUID="urn:uuid:1fcd2f32-6c99-11eb-a15d-ac1f6b9e3060"  Creator="tifffile.py 2020.12.8"><Image ID="Image:0" Name="Image0"><Pixels ID="Pixels:0" DimensionOrder="XYCZT" Type="double" SizeX="10" SizeY="10" SizeC="1" SizeZ="1" SizeT="1"><Channel ID="Channel:0:0" SamplesPerPixel="1"><LightPath/></Channel><TiffData IFD="0" PlaneCount="1"/></Pixels></Image><Image ID="Image:1" Name="Image1"><Pixels ID="Pixels:1" DimensionOrder="XYCZT" Type="double" SizeX="10" SizeY="10" SizeC="1" SizeZ="1" SizeT="1"><Channel ID="Channel:1:0" SamplesPerPixel="1"><LightPath/></Channel><TiffData IFD="1"/></Pixels></Image></OME>'

# %%
def rewrite_ome_tiff_header(tif_obj, out_fp, metadata):
    """add metadata to tif header"""
    w = tifffile.TiffWrite('../data/test5.ome.tiff', ome=True)
    for p in tif_obj.pages:
        tif.write(p.asarray())
    header = tif_obj.ome_metadata
    
    xml_str = ' '.join([f'{k}="{v}"' for k, v in metadata.items()])
    header.replace

# %% [markdown]
# ## generate file level metadata

# %%
fps = os_helpers.listfiles(f'../data/hyperion/{batch_folder}/ome-tiff_htan', regex=r'tiff$')
# fps = os_helpers.listfiles(f'../data/codex/{batch_folder}/ome-tiff_htan', regex=r'tiff$')
sample_fp_tups = [(fp.split('/')[-1].replace('.ome.tiff', ''), fp) for fp in fps]
sample_fp_tups
# Out:
# [('HT056P1_PA_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/H

#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H7_A1_A4_ROI_02.ome.tiff'),
#  ('HT060P1_PB_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT060P1_PB_A1_A4_ROI_02.ome.tiff'),
#  ('HT065B1_H3_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H3_A1_A4_ROI_03.ome.tiff'),
#  ('HT061P1_PC_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT061P1_PC_A1_A4_ROI_03.ome.tiff'),
#  ('HT064B1_H1_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H1_A1_A4_ROI_01.ome.tiff'),
#  ('HT055P1_PA_A1_A4_ROI_05',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT055P1_PA_A1_A4_ROI_05.ome.tiff'),
#  ('HT056P1_PB_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT056P1_PB_A1_A4_ROI_02.ome.tiff'),
#  ('HT065B1_H1_A1_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H1_A1_ROI_01.ome.tiff'),
#  ('HT081B1_H5_A1_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT081B1_H5_A1_ROI_01.ome.tiff'),
#  ('HT064B1_H9_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H9_A1_A4_ROI_01.ome.tiff'),
#  ('HT061P1_PA_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT061P1_PA_A1_A4_ROI_01.ome.tiff'),
#  ('HT081B1_H5_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT081B1_H5_A4_ROI_01.ome.tiff'),
#  ('HT064B1_H3_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H3_A1_A4_ROI_02.ome.tiff'),
#  ('human_spleen_HT093_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/human_spleen_HT093_ROI_02.ome.tiff'),
#  ('HT055P1_PA_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT055P1_PA_A1_A4_ROI_03.ome.tiff'),
#  ('HT069B1_H9_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT069B1_H9_A1_A4_ROI_01.ome.tiff'),
#  ('HT068B1_H2_ROI_05',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT068B1_H2_ROI_05.ome.tiff'),
#  ('HT081B1_H5_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT081B1_H5_A4_ROI_03.ome.tiff'),
#  ('HT068B1_H1_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT068B1_H1_ROI_02.ome.tiff'),
#  ('HT056P1_PB_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT056P1_PB_A1_A4_ROI_01.ome.tiff'),
#  ('HT060P1_PB_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT060P1_PB_A1_A4_ROI_01.ome.tiff'),
#  ('HT065B1_H1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H1_A4_ROI_01.ome.tiff'),
#  ('HT062B1_PB_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT062B1_PB_A1_A4_ROI_02.ome.tiff'),
#  ('HT065B1_H3_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H3_A1_A4_ROI_02.ome.tiff'),
#  ('HT069B1_H9_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT069B1_H9_A1_A4_ROI_03.ome.tiff')]

# %%
assay_type = 'IMC'
# assay_type = 'CODEX'

# %%
# im

# %%
df = pd.DataFrame.from_dict({
    'Component': ['ImagingLevel2'] * len(sample_fp_tups),
    'File Format': ['OME-TIFF'] * len(sample_fp_tups),
    'HTAN Participant ID': [''] * len(sample_fp_tups),
    'HTAN Parent Biospecimen ID': [''] * len(sample_fp_tups),
    'HTAN Data File ID': [''] * len(sample_fp_tups),
#     'HTAN Parent Data File ID': ['matt provides'] * len(sample_fp_tups),
    'Imaging Assay Type': [assay_type] * len(sample_fp_tups),
    'Protocol Link': [''] * len(sample_fp_tups),
    'Workflow Start Datetime': [''] * len(sample_fp_tups),
    'Workflow End Datetime': [''] * len(sample_fp_tups),
    'Software and Version': [''] * len(sample_fp_tups),
    'Image Acquisition Date': [''] * len(sample_fp_tups),
    'Microscope': [''] * len(sample_fp_tups),
    'Objective': [''] * len(sample_fp_tups),
    'NominalMagnification': [''] * len(sample_fp_tups),
    'LensNA': [''] * len(sample_fp_tups),
    'WorkingDistance': [''] * len(sample_fp_tups),
    'WorkingDistanceUnit': [''] * len(sample_fp_tups),
    'Immersion': [''] * len(sample_fp_tups),
    'Passed QC': [True] * len(sample_fp_tups),
    'Pyramid': [False] * len(sample_fp_tups),
    'Tseries': [False] * len(sample_fp_tups),
    'Zstack': [False] * len(sample_fp_tups),
    'Comment': [''] * len(sample_fp_tups),
    'FOV number': [''] * len(sample_fp_tups),
    'FOVX': [''] * len(sample_fp_tups),
    'FOVXUnit': [''] * len(sample_fp_tups),
    'FOVY': [''] * len(sample_fp_tups),
    'FOVYUnit': [''] * len(sample_fp_tups),
    'Frame Averaging': [''] * len(sample_fp_tups),
    'PhysicalSizeZ': [''] * len(sample_fp_tups),
    'PhysicalSizeZUnit': [''] * len(sample_fp_tups)
})

fns, imid, do, psx, pux, psy, puy, pbe, pc, sc, st, sx, sy, sz, pt = [[] for x in range(15)]
for sample, fp in sample_fp_tups:
    tif = TiffFile(fp)
    ome = from_xml(tif.ome_metadata)
    im = ome.images[0]
    
    fns.append(fp.split('/')[-1])
    imid.append(im.id)
    do.append(im.pixels.dimension_order.value)
    psx.append(im.pixels.physical_size_x)
    pux.append(im.pixels.physical_size_x_unit.value)
    psy.append(im.pixels.physical_size_y)
    puy.append(im.pixels.physical_size_y_unit.value)
    pbe.append(im.pixels.big_endian)
    pc.append(im.pixels.tiff_data_blocks[0].plane_count)
    sc.append(im.pixels.size_c)
    st.append(im.pixels.size_t)
    sx.append(im.pixels.size_x)
    sy.append(im.pixels.size_y)
    sz.append(im.pixels.size_z)
    pt.append(im.pixels.type.value)
    
df = pd.merge(df,
             pd.DataFrame.from_dict({
                 'Filename': fns,
                 'Channel Metadata Filename': [f.replace('.ome.tiff', '.csv') for f in fns],
                 'Image ID': imid,
                 'DimensionOrder': do,
                 'PhysicalSizeX': psx,
                 'PhysicalSizeXUnit': pux,
                 'PhysicalSizeY': psy,
                 'PhysicalSizeYUnit': puy,
                 'Pixels BigEndian': pbe,
                 'PlaneCount': pc,
                 'SizeC': sc,
                 'SizeT': st,
                 'SizeX': sx,
                 'SizeY': sy,
                 'SizeZ': sz,
                 'PixelType': pt
             }), left_index=True, right_index=True)

order = ['Component', 'Filename', 'File Format', 'HTAN Participant ID', 'HTAN Parent Biospecimen ID',
         'HTAN Data File ID', 'Channel Metadata Filename', 'Imaging Assay Type', 'Protocol Link',
         'Workflow Start Datetime', 'Workflow End Datetime', 'Software and Version',
         'Image Acquisition Date', 'Microscope', 'Objective', 'NominalMagnification', 'LensNA', 'WorkingDistance',
         'WorkingDistanceUnit', 'Immersion', 'Passed QC', 'Pyramid', 'Tseries', 'Zstack', 'Comment',
         'FOV number', 'FOVX', 'FOVXUnit', 'FOVY', 'FOVYUnit', 'Frame Averaging',
        'Image ID', 'DimensionOrder', 'PhysicalSizeX', 'PhysicalSizeXUnit', 'PhysicalSizeY', 'PhysicalSizeYUnit',
         'PhysicalSizeZ', 'PhysicalSizeZUnit',
        'Pixels BigEndian', 'PlaneCount', 'SizeC', 'SizeT', 'SizeX', 'SizeY', 'SizeZ', 'PixelType']

df = df[order]
df
# Out:
#         Component                            Filename File Format  \
# 0   ImagingLevel2    HT056P1_PA_A1_A4_ROI_02.ome.tiff    OME-TIFF
# 1   ImagingLevel2       HT065B1_H1_A4_ROI_02.ome.tiff    OME-TIFF
# 2   ImagingLevel2    HT064B1_H3_A1_A4_ROI_01.ome.tiff    OME-TIFF
# 3   ImagingLevel2    HT064B1_H1_A1_A4_ROI_02.ome.tiff    OME-TIFF
# 4   ImagingLevel2  human_spleen_HT093_ROI_01.ome.tiff    OME-TIFF
# ..            ...                                 ...         ...
# 77  ImagingLevel2    HT060P1_PB_A1_A4_ROI_01.ome.tiff    OME-TIFF
# 78  ImagingLevel2       HT065B1_H1_A4_ROI_01.ome.tiff    OME-TIFF
# 79  ImagingLevel2    HT062B1_PB_A1_A4_ROI_02.ome.tiff    OME-TIFF
# 80  ImagingLevel2    HT065B1_H3_A1_A4_ROI_02.ome.tiff    OME-TIFF
# 81  ImagingLevel2    HT069B1_H9_A1_A4_ROI_03.ome.tiff    OME-TIFF
#
#    HTAN Participant ID HTAN Parent Biospecimen ID HTAN Data File ID  \
# 0
# 1
# 2
# 3
# 4
# ..                 ...                        ...               ...
# 77
# 78
# 79
# 80
# 81
#
#         Channel Metadata Filename Imaging Assay Type Protocol Link  \
# 0     HT056P1_PA_A1_A4_ROI_02.csv                IMC
# 1        HT065B1_H1_A4_ROI_02.csv                IMC
# 2     HT064B1_H3_A1_A4_ROI_01.csv                IMC
# 3     HT064B1_H1_A1_A4_ROI_02.csv                IMC
# 4   human_spleen_HT093_ROI_01.csv                IMC
# ..                            ...                ...           ...
# 77    HT060P1_PB_A1_A4_ROI_01.csv                IMC
# 78       HT065B1_H1_A4_ROI_01.csv                IMC
# 79    HT062B1_PB_A1_A4_ROI_02.csv                IMC
# 80    HT065B1_H3_A1_A4_ROI_02.csv                IMC
# 81    HT069B1_H9_A1_A4_ROI_03.csv                IMC
#
#    Workflow Start Datetime  ... PhysicalSizeZ PhysicalSizeZUnit  \
# 0                           ...
# 1                           ...
# 2                           ...
# 3                           ...
# 4                           ...
# ..                     ...  ...           ...               ...
# 77                          ...
# 78                          ...
# 79                          ...
# 80                          ...
# 81                          ...
#
#    Pixels BigEndian PlaneCount SizeC SizeT SizeX SizeY SizeZ PixelType
# 0             False         28    28     1   636   567     1     float
# 1             False         28    28     1   473   419     1     float
# 2             False         28    28     1   495   351     1     float
# 3             False         28    28     1   280   368     1     float
# 4             False         28    28     1   153    92     1     float
# ..              ...        ...   ...   ...   ...   ...   ...       ...
# 77            False         28    28     1   779   413     1     float
# 78            False         28    28     1   558   461     1     float
# 79            False         28    28     1   673   468     1     float
# 80            False         28    28     1   460   572     1     float
# 81            False         28    28     1   635   655     1     float
#
# [82 rows x 47 columns]

# %%
h = 'hyperion' if assay_type == 'IMC' else 'codex'
df.to_csv(f'../data/{h}/{batch_folder}/file_level_metadata.csv', sep=',', index=False)

# %% [markdown]
# ## generate channel level metadata

# %%
fps = os_helpers.listfiles(f'../data/hyperion/{batch_folder}/ome-tiff_htan', regex=r'tiff$')
# fps = os_helpers.listfiles(f'../data/codex/{batch_folder}/ome-tiff_htan', regex=r'tiff$')
sample_fp_tups = [(fp.split('/')[-1].replace('.ome.tiff', ''), fp) for fp in fps]
sample_fp_tups
# Out:
# [('HT056P1_PA_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT056P1_PA_A1_A4_ROI_02.ome.tiff'),
#  ('HT065B1_H1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H1_A4_ROI_02.ome.tiff'),
#  ('HT064B1_H3_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H3_A1_A4_ROI_01.ome.tiff'),
#  ('HT064B1_H1_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H1_A1_A4_ROI_02.ome.tiff'),
#  ('human_spleen_HT093_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/human_spleen_HT093_ROI_01.ome.tiff'),
#  ('HT062B1_PA_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT062B1_PA_ROI_03.ome.tiff'),
#  ('HT061P1_PA_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT061P1_PA_A1_A4_ROI_02.ome.tiff'),
#  ('HT060P1_PA_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT060P1_PA_A1_A4_ROI_01.ome.tiff'),
#  ('HT056P1_PB_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT056P1_PB_A1_A4_ROI_03.ome.tiff'),
#  ('HT064B1_H1_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H1_A1_A4_ROI_03.ome.tiff'),
#  ('HT061P1_PB_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT061P1_PB_A1_A4_ROI_02.ome.tiff'),
#  ('HT060P1_REMAIN_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT060P1_REMAIN_ROI_03.ome.tiff'),
#  ('HT081B1_H5_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT081B1_H5_A4_ROI_02.ome.tiff'),
#  ('HT055P1_PA_A1_A4_ROI_04',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT055P1_PA_A1_A4_ROI_04.ome.tiff'),
#  ('HT065B1_H3_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H3_A1_A4_ROI_01.ome.tiff'),
#  ('HT055P1_PA_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT055P1_PA_A1_A4_ROI_01.ome.tiff'),
#  ('HT061P1_PC_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT061P1_PC_A1_A4_ROI_02.ome.tiff'),
#  ('HT060P1_PB_A1_A4_ROI_04',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT060P1_PB_A1_A4_ROI_04.ome.tiff'),
#  ('HT064B1_H7_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H7_A1_A4_ROI_03.ome.tiff'),
#  ('HT065B1_H7_A1_A4_ROI_01',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H7_A1_A4_ROI_01.ome.tiff'),
#  ('HT061P1_PB_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/H

#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT062B1_PB_A1_A4_ROI_02.ome.tiff'),
#  ('HT065B1_H3_A1_A4_ROI_02',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H3_A1_A4_ROI_02.ome.tiff'),
#  ('HT069B1_H9_A1_A4_ROI_03',
#   '../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT069B1_H9_A1_A4_ROI_03.ome.tiff')]

# %%
out_dir = f'../data/hyperion/{batch_folder}/ome-tiff_htan'
# out_dir = f'../data/codex/{batch_folder}/ome-tiff_htan'
Path(out_dir).mkdir(exist_ok=True, parents=True)

# %%
for sample, fp in sample_fp_tups:
    channel_id, channel_name = [], []
    print(sample, fp)
    tif = TiffFile(fp)
    m = re.sub(r'<Acquis.*AcquisitionDate>', r'', tif.ome_metadata)
    ome = from_xml(m)
    im = ome.images[0]
    for channel in im.pixels.channels:
        channel_id.append(channel.id)
        channel_name.append(channel.name)
        
    df = pd.DataFrame.from_dict({
        'Channel ID': channel_id,
        'Channel Name': channel_name,
        'Passed QC': [True] * len(channel_name)
    })
    df.to_csv(fp.replace('.ome.tiff', '.csv'), sep=',', index=False)
# Out:
# HT056P1_PA_A1_A4_ROI_02 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT056P1_PA_A1_A4_ROI_02.ome.tiff
# HT065B1_H1_A4_ROI_02 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H1_A4_ROI_02.ome.tiff
# HT064B1_H3_A1_A4_ROI_01 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H3_A1_A4_ROI_01.ome.tiff
# HT064B1_H1_A1_A4_ROI_02 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H1_A1_A4_ROI_02.ome.tiff
# human_spleen_HT093_ROI_01 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/human_spleen_HT093_ROI_01.ome.tiff
# HT062B1_PA_ROI_03 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT062B1_PA_ROI_03.ome.tiff
# HT061P1_PA_A1_A4_ROI_02 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT061P1_PA_A1_A4_ROI_02.ome.tiff
# HT060P1_PA_A1_A4_ROI_01 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT060P1_PA_A1_A4_ROI_01.ome.tiff
# HT056P1_PB_A1_A4_ROI_03 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT056P1_PB_A1_A4_ROI_03.ome.tiff
# HT064B1_H1_A1_A4_ROI_03 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H1_A1_A4_ROI_03.ome.tiff
# HT061P1_PB_A1_A4_ROI_02 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT061P1_PB_A1_A4_ROI_02.ome.tiff
# HT060P1_REMAIN_ROI_03 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT060P1_REMAIN_ROI_03.ome.tiff
# HT081B1_H5_A4_ROI_02 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT081B1_H5_A4_ROI_02.ome.tiff
# HT055P1_PA_A1_A4_ROI_04 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT055P1_PA_A1_A4_ROI_04.ome.tiff
# HT065B1_H3_A1_A4_ROI_01 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT065B1_H3_A1_A4_ROI_01.ome.tiff
# HT055P1_PA_A1_A4_ROI_01 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT055P1_PA_A1_A4_ROI_01.ome.tiff
# HT061P1_PC_A1_A4_ROI_02 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT061P1_PC_A1_A4_ROI_02.ome.tiff
# HT060P1_PB_A1_A4_ROI_04 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT060P1_PB_A1_A4_ROI_04.ome.tiff
# HT064B1_H7_A1_A4_ROI_03 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/HT064B1_H7_A1_A4_ROI_03.ome.tiff
# HT065B1_H7_A1_A4_ROI_01 ../data/hyperion/b1_01042020_processed_10072021/ome-tiff_htan/H